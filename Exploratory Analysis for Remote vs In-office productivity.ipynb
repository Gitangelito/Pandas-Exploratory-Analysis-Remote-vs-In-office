# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\maste\Desktop\Remote work productivity - Kaggle\remote_work_productivity.csv")
df
# Out:
#      Employee_ID Employment_Type  Hours_Worked_Per_Week  Productivity_Score  \
# 0              1          Remote                     29                  75
# 1              2       In-Office                     45                  49
# 2              3          Remote                     34                  74
# 3              4          Remote                     25                  81
# 4              5          Remote                     50                  70
# ..           ...             ...                    ...                 ...
# 995          996          Remote                     33                  88
# 996          997          Remote                     33                  88
# 997          998       In-Office                     45                  74
# 998          999       In-Office                     57                  50
# 999         1000          Remote                     34                  80
#
#      Well_Being_Score
# 0                  78
# ...

# %%
df.shape
# Out:
# (1000, 5)

# %%
df.head(10)
# Out:
#    Employee_ID Employment_Type  Hours_Worked_Per_Week  Productivity_Score  \
# 0            1          Remote                     29                  75
# 1            2       In-Office                     45                  49
# 2            3          Remote                     34                  74
# 3            4          Remote                     25                  81
# 4            5          Remote                     50                  70
# 5            6       In-Office                     48                  66
# 6            7          Remote                     38                  44
# 7            8          Remote                     35                  72
# 8            9          Remote                     30                  70
# 9           10       In-Office                     40                  59
#
#    Well_Being_Score
# 0                78
# 1                47
# 2                89
# 3                84
# 4                74
# 5                58
# ...

# %%
df.dtypes
# Out:
# Employee_ID               int64
# Employment_Type          object
# Hours_Worked_Per_Week     int64
# Productivity_Score        int64
# Well_Being_Score          int64
# dtype: object

# %%
df.describe()
# Out:
#        Employee_ID  Hours_Worked_Per_Week  Productivity_Score  \
# count  1000.000000            1000.000000         1000.000000
# mean    500.500000              39.720000           68.602000
# std     288.819436               8.042779           12.235494
# min       1.000000              16.000000           33.000000
# 25%     250.750000              34.750000           60.000000
# 50%     500.500000              40.000000           68.000000
# 75%     750.250000              45.000000           76.000000
# max    1000.000000              64.000000          112.000000
#
#        Well_Being_Score
# count       1000.000000
# mean          63.975000
# std           13.870572
# min           14.000000
# 25%           56.000000
# 50%           65.000000
# 75%           73.000000
# max          104.000000

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Employment_Type        1000 non-null   object
#  2   Hours_Worked_Per_Week  1000 non-null   int64
#  3   Productivity_Score     1000 non-null   int64
#  4   Well_Being_Score       1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB

# %%
df.boxplot(figsize=(20,10))
# Out:
# <Axes: >

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Employee_ID'}>,
#         <Axes: title={'center': 'Hours_Worked_Per_Week'}>],
#        [<Axes: title={'center': 'Productivity_Score'}>,
#         <Axes: title={'center': 'Well_Being_Score'}>]], dtype=object)

# %%
df[['Hours_Worked_Per_Week','Productivity_Score','Well_Being_Score']].plot.hist(alpha=0.5);

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(15, 9),);

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Employment_Type', 'Hours_Worked_Per_Week',
#        'Productivity_Score', 'Well_Being_Score'],
#       dtype='object')

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            1000 non-null   int64
#  1   Employment_Type        1000 non-null   object
#  2   Hours_Worked_Per_Week  1000 non-null   int64
#  3   Productivity_Score     1000 non-null   int64
#  4   Well_Being_Score       1000 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 39.2+ KB
# None
#        Employee_ID  Hours_Worked_Per_Week  Productivity_Score  \
# count  1000.000000            1000.000000         1000.000000
# mean    500.500000              39.720000           68.602000
# std     288.819436               8.042779           12.235494
# min       1.000000              16.000000           33.000000
# 25%     250.750000              34.750000           60.000000
# 50%     500.500000              40.000000           68.000000
# ...

# %%
print(df.isnull().sum())
# Out:
# Employee_ID              0
# Employment_Type          0
# Hours_Worked_Per_Week    0
# Productivity_Score       0
# Well_Being_Score         0
# dtype: int64

# %%
print(df['Employment_Type'].value_counts())
# Out:
# Employment_Type
# In-Office    510
# Remote       490
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {'Employment_Type': ['In-Office', 'Remote'],
        'Count': [510, 490]}

# Create a DataFrame
df = pd.DataFrame(data)

# Count the occurrences of each employment type
employment_type_counts = df['Employment_Type'].value_counts()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(df['Count'], labels=df['Employment_Type'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Employment Types')
plt.axis('equal')  # Equal aspect ratio ensures a circular pie chart
plt.show()

# %%
#Analizing relationships:

import pandas as pd
import seaborn as sns

sns.pairplot(df)
plt.show()

# %%
import pandas as pd
import numpy as np

# Select numerical columns
numerical_columns = df.select_dtypes(include=[np.number])

# Calculate correlation matrix
correlation_matrix = numerical_columns.corr()

# Create heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
#Hypothesis testing:

# Test if there's a significant difference in productivity between employment types
#from scipy.stats import ttest_ind
# ... (perform t-test)

# %%
#import matplotlib.pyplot as plt

#plt.scatter(y_test, y_pred)
#plt.xlabel('Actual Productivity')
#plt.ylabel('Predicted Productivity')
#plt.show()

# %%
# Analyze the model's coefficients to understand the impact of features on productivity
#print(model.coef_)

# %%
print(df['Count'].value_counts())
# Out:
# Count
# 510    1
# 490    1
# Name: count, dtype: int64

# %%
import pandas as pd
import sys
# !{sys.executable} -m pip install ydata_profiling

# %%
import ydata_profiling as pp
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\Users\maste\Desktop\Remote work productivity - Kaggle\remote_work_productivity.csv")

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
profile = pp.ProfileReport(df)

# %%
profile.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
profile.to_file("report.html")
# Out:
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
